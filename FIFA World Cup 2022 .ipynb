# %%
#import libraries

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
#Read the data

df = pd.read_csv(r"C:\Users\Administrator\Downloads\FIFA\FIFA - 2022.csv")

# %%
#Display Data

df
# Out:
#     Position          Team  Games Played  Win  Draw  Loss  Goals For  \
# 0          1     Argentina             7    6     0     1         15
# 1          2        France             7    5     0     2         16
# 2          3       Croatia             7    4     2     1          8
# 3          4       Morocco             7    4     1     2          6
# 4          5       England             5    3     1     1         13
# 5          6   Netherlands             5    3     1     1         10
# 6          7      Portugal             5    3     0     2         12
# 7          8        Brazil             5    3     0     2          8
# 8          9         Japan             4    2     0     2          5
# 9         10       Senegal             4    2     0     2          5
# 10        11     Australia             4    2     0     2          4
# 11        12   Switzerland             4    2     0     2          5
# 12        13           USA             4    1     2     1          3
# ...

# %%
#Data types in columns

df.dtypes
# Out:
# Position            int64
# Team               object
# Games Played        int64
# Win                 int64
# Draw                int64
# Loss                int64
# Goals For           int64
# Goals Against       int64
# Goal Difference     int64
# Points              int64
# dtype: object

# %%
#Display Missing Data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} -{}%'.format(col,pct_missing))
# Out:
# Position -0.0%
# Team -0.0%
# Games Played -0.0%
# Win -0.0%
# Draw -0.0%
# Loss -0.0%
# Goals For -0.0%
# Goals Against -0.0%
# Goal Difference -0.0%
# Points -0.0%

# %%
# Are there any Outliers?

df.boxplot( column = 'Position' )
# Out:
# <Axes: >

# %%
#Dropping of duplicates

df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of     Position          Team  Games Played  Win  Draw  Loss  Goals For  \
# 0          1     Argentina             7    6     0     1         15
# 1          2        France             7    5     0     2         16
# 2          3       Croatia             7    4     2     1          8
# 3          4       Morocco             7    4     1     2          6
# 4          5       England             5    3     1     1         13
# 5          6   Netherlands             5    3     1     1         10
# 6          7      Portugal             5    3     0     2         12
# 7          8        Brazil             5    3     0     2          8
# 8          9         Japan             4    2     0     2          5
# 9         10       Senegal             4    2     0     2          5
# 10        11     Australia             4    2     0     2          4
# 11        12   Switzerland             4    2     0     2          5
# ...

# %%
# Order our Data a little bit to see

df.sort_values(by=['Position'], inplace=False, ascending=True)
# Out:
#     Position          Team  Games Played  Win  Draw  Loss  Goals For  \
# 0          1     Argentina             7    6     0     1         15
# 1          2        France             7    5     0     2         16
# 2          3       Croatia             7    4     2     1          8
# 3          4       Morocco             7    4     1     2          6
# 4          5       England             5    3     1     1         13
# 5          6   Netherlands             5    3     1     1         10
# 6          7      Portugal             5    3     0     2         12
# 7          8        Brazil             5    3     0     2          8
# 8          9         Japan             4    2     0     2          5
# 9         10       Senegal             4    2     0     2          5
# 10        11     Australia             4    2     0     2          4
# 11        12   Switzerland             4    2     0     2          5
# 12        13           USA             4    1     2     1          3
# ...

# %%
#Plot the dataset

sns.regplot(x="Position", y="Win", data=df)
# Out:
# <Axes: xlabel='Position', ylabel='Win'>

# %%
#Plot the dataset

sns.regplot(x="Position", y="Draw", data=df)
# Out:
# <Axes: xlabel='Position', ylabel='Draw'>

# %%
#Plot the dataset

sns.regplot(x="Position", y="Loss", data=df)
# Out:
# <Axes: xlabel='Position', ylabel='Loss'>

# %%
correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for FIFA")

plt.xlabel("FIFA")

plt.ylabel("FIFA")

plt.show()

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# Position  Position           1.000000
#           Team               1.000000
#           Games Played       0.899750
#           Win                0.888194
#           Draw               0.101583
#                                ...
# Points    Loss               0.365053
#           Goals For          0.828819
#           Goals Against      0.212752
#           Goal Difference    0.767797
#           Points             1.000000
# Length: 100, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# Draw             Loss              -0.520119
# Loss             Draw              -0.520119
# Goals Against    Loss              -0.283762
# Loss             Goals Against     -0.283762
# Goal Difference  Draw               0.039789
#                                       ...
# Team             Team               1.000000
#                  Position           1.000000
# Position         Team               1.000000
# Goal Difference  Goal Difference    1.000000
# Points           Points             1.000000
# Length: 100, dtype: float64

# %%
# We can now take a look at the ones that have a high correlation (> 0.5)

strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# Draw             Loss              -0.520119
# Loss             Draw              -0.520119
# Goal Difference  Games Played       0.699327
# Games Played     Goal Difference    0.699327
# Win              Goal Difference    0.744749
# Goal Difference  Win                0.744749
#                  Goals For          0.761628
# Goals For        Goal Difference    0.761628
# Goal Difference  Points             0.767797
# Points           Goal Difference    0.767797
# Goals For        Team               0.788455
#                  Position           0.788455
# Team             Goals For          0.788455
# Position         Goals For          0.788455
# Goal Difference  Position           0.798967
# Team             Goal Difference    0.798967
# Position         Goal Difference    0.798967
# Goal Difference  Team               0.798967
# Goals For        Games Played       0.806076
# Games Played     Goals For          0.806076
# Goals For        Points             0.828819
# ...

# %%
df
# Out:
#     Position          Team  Games Played  Win  Draw  Loss  Goals For  \
# 0          1     Argentina             7    6     0     1         15
# 1          2        France             7    5     0     2         16
# 2          3       Croatia             7    4     2     1          8
# 3          4       Morocco             7    4     1     2          6
# 4          5       England             5    3     1     1         13
# 5          6   Netherlands             5    3     1     1         10
# 6          7      Portugal             5    3     0     2         12
# 7          8        Brazil             5    3     0     2          8
# 8          9         Japan             4    2     0     2          5
# 9         10       Senegal             4    2     0     2          5
# 10        11     Australia             4    2     0     2          4
# 11        12   Switzerland             4    2     0     2          5
# 12        13           USA             4    1     2     1          3
# ...
